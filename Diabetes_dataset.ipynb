# %% [markdown]
# <a href="https://colab.research.google.com/github/GOWRISHANKARK80/Diabetes-prediction-database/blob/main/Diabetes_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diabetes_prediction_dataset.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
df[(df["gender"]=="Male") & (df["diabetes"]==1)].loc[:,["gender","diabetes"]]
# Out:
#       gender  diabetes
# 26      Male         1
# 38      Male         1
# 40      Male         1
# 55      Male         1
# 81      Male         1
# ...      ...       ...
# 99826   Male         1
# 99829   Male         1
# 99867   Male         1
# 99897   Male         1
# 99938   Male         1
#
# [4039 rows x 2 columns]

# %%
df[(df["gender"]=="Male") & (df["diabetes"]==1)].loc[:,["gender","diabetes"]].value_counts()
# Out:
# gender  diabetes
# Male    1           4039
# Name: count, dtype: int64

# %%
df[df["gender"]=="Male"][df["diabetes"]==1].value_counts()
# Out:
# <ipython-input-53-2265ca90ed25>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["gender"]=="Male"][df["diabetes"]==1].value_counts()
# gender  age   hypertension  heart_disease  smoking_history  bmi    HbA1c_level  blood_glucose_level  diabetes
# Male    60.0  0             0              never            27.32  6.5          300                  1           2
#         38.0  0             0              No Info          31.85  5.7          220                  1           2
#         66.0  0             0              No Info          27.32  5.7          130                  1           2
#         49.0  0             0              never            27.32  6.2          240                  1           2
#         3.0   0             0              No Info          27.32  5.7          200                  1           1
#                                                                                                                 ..
# ...

# %%
df[(df["gender"]=="Female") & (df["diabetes"]==1)].loc[:,["gender","diabetes"]]
# Out:
#        gender  diabetes
# 6      Female         1
# 53     Female         1
# 59     Female         1
# 87     Female         1
# 94     Female         1
# ...       ...       ...
# 99929  Female         1
# 99935  Female         1
# 99957  Female         1
# 99962  Female         1
# 99979  Female         1
#
# [4461 rows x 2 columns]

# %%
df[df["gender"]=="Female"][df["diabetes"]==1].value_counts()
# Out:
# <ipython-input-54-49ee9d20bce2>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["gender"]=="Female"][df["diabetes"]==1].value_counts()
# gender  age   hypertension  heart_disease  smoking_history  bmi    HbA1c_level  blood_glucose_level  diabetes
# Female  80.0  0             0              never            27.32  8.2          280                  1           3
#                                            No Info          27.32  6.5          240                  1           2
#               1             0              No Info          27.32  7.5          160                  1           2
#               0             0              No Info          27.32  8.8          240                  1           2
#         53.0  0             0              never            27.32  6.6          155                  1           2
#                                                                                                                 ..
# ...

# %%
df[df["gender"].isin(["Male","Female"])][df["diabetes"]==1].value_counts()
# Out:
# <ipython-input-61-cc2d66925cc8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["gender"].isin(["Male","Female"])][df["diabetes"]==1].value_counts()
# gender  age   hypertension  heart_disease  smoking_history  bmi    HbA1c_level  blood_glucose_level  diabetes
# Female  80.0  0             0              never            27.32  8.2          280                  1           3
# Male    38.0  0             0              No Info          31.85  5.7          220                  1           2
# Female  80.0  0             0              never            27.32  5.8          280                  1           2
#                                            No Info          27.32  8.8          240                  1           2
#                                                                    9.0          220                  1           2
# ...

# %%
df[(df["blood_glucose_level"]>=200) & (df["hypertension"]==1) & (df["heart_disease"]==1) & df["smoking_history"].isin(["current","not current"]) & (df["diabetes"]==0)]
# Out:
# gender  age   hypertension  heart_disease  smoking_history  bmi    HbA1c_level  blood_glucose_level  diabetes
# Female  63.0  1             1              current          34.32  4.8          200                  0           1
#         76.0  1             1              not current      27.32  5.7          200                  0           1
# Male    57.0  1             1              not current      27.63  5.0          200                  0           1
# Name: count, dtype: int64

# %%
df[df["gender"].isin(["Male","Female"])][df["blood_glucose_level"]>=200]
# Out:
# <ipython-input-48-41beda2725bf>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["gender"].isin(["Male","Female"])][df["blood_glucose_level"]>=200]
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 6      Female  44.0             0              0           never  19.31
# 13     Female  67.0             0              0           never  25.69
# 16       Male  15.0             0              0           never  30.36
# 26       Male  67.0             0              1     not current  27.32
# 30     Female  53.0             0              0         No Info  31.75
# ...       ...   ...           ...            ...             ...    ...
# 99938    Male  55.0             0              1          former  30.42
# 99941  Female  38.0             0              0         No Info  32.66
# 99957  Female  61.0             0              0         No Info  34.45
# ...

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
df["gender"][df["blood_glucose_level"]>=200].value_counts()
# Out:
# gender
# Female    6131
# Male      4745
# Other        1
# Name: count, dtype: int64

# %%
df["gender"][df["blood_glucose_level"]>=200][df["hypertension"]==1].value_counts()
# Out:
# gender
# Female    751
# Male      623
# Name: count, dtype: int64

# %%
df["gender"][df["blood_glucose_level"]>=200][df["hypertension"]==1][df["heart_disease"]==1].value_counts()
# Out:
# gender
# Female    105
# Male      100
# Name: count, dtype: int64

# %%
df["gender"][df["blood_glucose_level"]>=200][df["hypertension"]==1][df["heart_disease"]==1][df["smoking_history"].isin(["current","not current"])].value_counts()
# Out:
# gender
# Male      19
# Female    16
# Name: count, dtype: int64

# %%
df["gender"][df["blood_glucose_level"]>=200][df["hypertension"]==1][df["heart_disease"]==1][df["smoking_history"].isin(["current","not current"])][df["diabetes"]==0].value_counts()
# Out:
# gender
# Female    2
# Male      1
# Name: count, dtype: int64
